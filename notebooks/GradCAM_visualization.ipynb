# %% [markdown]
# # Grad-CAM Visualization and Localization Confidence Analysis

# %% [markdown]
# ### Interpretable Fracture Localization for Hybrid CNN-Based Screening

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# from model import FractureNet
# from dataset import MURADataset
# from evaluate import GradCAM, overlay_cam, cam_entropy

# %%
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# torch: 2.6.0+cu124
# cuda in torch: 12.4
# cuda available: True
